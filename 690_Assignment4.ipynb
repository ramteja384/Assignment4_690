# %%
import pandas as pd

data = pd.read_csv("MERGED2017_18_PP.csv")
data.head()
# Out:
# C:\Users\ramch\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# Number of colleges

# %%
print(len(data))
# Out:
# 7112

# %% [markdown]
# Number of variables

# %%
print(len(data.columns))
# Out:
# 1986

# %% [markdown]
# First 5 colleges

# %%
data.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# Last 5 colleges

# %%
data.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# Random sample of 5 colleges

# %%
data.sample(5)
# Out:
#       UNITID    OPEID  OPEID6  \
# 6472  487481  2305812   23058
# 1147  152628  1015100   10151
# 2738  204422   531300    5313
# 5295  449816  4054300   40543
# 4781  436270  3030601   30306
#
#                                                  INSTNM        CITY STABBR  \
# 6472  United Education Institute - UEI College - Pho...     Phoenix     AZ
# 1147                           Vincennes Beauty College   Vincennes     IN
# 2738                        North Central State College   Mansfield     OH
# 5295                        Southwest Technical College  Cedar City     UT
# 4781                             Cortiva Institute-Orem        Orem     UT
#
#              ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 6472  85021-2718           NaN      NaN     NaN  ...
# 1147       47591           NaN      NaN     NaN  ...
# 2738  44901-0698           NaN      NaN     NaN  ...
# 5295       84720           NaN      NaN     NaN  ...
# 4781       84057           NaN      NaN     NaN  ...
#
# ...

# %% [markdown]
# Dataframe with required 9 variables

# %%
df = data[['UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'ADM_RATE', 'UGDS', 'TUITIONFEE_IN', 'MN_EARN_WNE_P10']]
print(df.head())
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %% [markdown]
# *Definitions of the 9 Variables/Columns
# **UNTID:- UNITID is a Unique Identification number assigned to postsecondary institutions.
# **INSTNM:- INSTNM represents the name of the institution.
# **CITY:- CITY includes all the cities in which each Institution is located.
# **STABBR:- Represents the location of the institution.
# **ZIP:- Includes the area code or Zip code of that particular institution.
# **ADM_RATE:- ADM_RATE includes the admissions rate at each campus.
# **UGDS:- UGDS includes the total enrollment of Undergraduate Degree-Seeking students.
# **TUITIONFEE_IN:- Includes the in-state tutiton fee details of the students
# **MN_EARN_WNE_P:- MN_EARN_WNE_P earnings are for the institutional aggregate of all federally aided students who enroll in an institution each year.

# %% [markdown]
# 1st 10 colleges

# %%
print(df.head(10))
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# last 10 colleges

# %%
print(df.tail(10))
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# 10 colleges Random sample

# %%
df.sample(10)
# Out:
#       UNITID                                      INSTNM         CITY STABBR  \
# 4846  439491                Blue Cliff College-Lafayette    Lafayette     LA
# 6424  486567              Paul Mitchell the School-Tulsa        Tulsa     OK
# 3563  229267                          Trinity University  San Antonio     TX
# 6485  487773  Butte County Regional Occupational Program        Chico     CA
# 1248  155104               Garden City Community College  Garden City     KS
# 5310  450003            Miami-Jacobs Career College-Troy         Troy     OH
# 567   127884                    Pueblo Community College       Pueblo     CO
# 843   140243                    Lanier Technical College  Gainesville     GA
# 1009  147031        Meadville Lombard Theological School      Chicago     IL
# 506   125170                       Berkeley City College     Berkeley     CA
#
#              ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# ...

# %% [markdown]
# Find and displaying UMBC

# %%
df1 = pd.DataFrame(columns=['UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'ADM_RATE', 'UGDS', 'TUITIONFEE_IN', 'MN_EARN_WNE_P10'])
for index in range(len(df)):
  if df.loc[index,'INSTNM'] == 'University of Maryland-Baltimore County':
    print(df.loc[index])
    df1 = df1.append(df.loc[index])
# Out:
# UNITID                                              163268
# INSTNM             University of Maryland-Baltimore County
# CITY                                             Baltimore
# STABBR                                                  MD
# ZIP                                                  21250
# ADM_RATE                                            0.6021
# UGDS                                                 11130
# TUITIONFEE_IN                                        11518
# MN_EARN_WNE_P10                                        NaN
# Name: 1478, dtype: object

# %% [markdown]
# Finding UMD

# %%
for index in range(len(df)):
  if df.loc[index,'INSTNM'] == 'University of Maryland-College Park':
    print(df.loc[index])
    df1 = df1.append(df.loc[index])
# Out:
# UNITID                                          163286
# INSTNM             University of Maryland-College Park
# CITY                                      College Park
# STABBR                                              MD
# ZIP                                              20742
# ADM_RATE                                         0.445
# UGDS                                             29273
# TUITIONFEE_IN                                    10399
# MN_EARN_WNE_P10                                    NaN
# Name: 1479, dtype: object

# %% [markdown]
# Finding Loyola

# %%
for index in range(len(df)):
  if df.loc[index,'INSTNM'] == 'Loyola University Maryland':
    print(df.loc[index])
    df1 = df1.append(df.loc[index])
# Out:
# UNITID                                 163046
# INSTNM             Loyola University Maryland
# CITY                                Baltimore
# STABBR                                     MD
# ZIP                                21210-2699
# ADM_RATE                               0.7528
# UGDS                                     3903
# TUITIONFEE_IN                           47560
# MN_EARN_WNE_P10                           NaN
# Name: 1475, dtype: object

# %% [markdown]
# Find and displaying Johns Hopkins

# %%
for index in range(len(df)):
  if df.loc[index,'INSTNM'] == 'Johns Hopkins University':
    print(df.loc[index])
    df1 = df1.append(df.loc[index])
# Out:
# UNITID                               162928
# INSTNM             Johns Hopkins University
# CITY                              Baltimore
# STABBR                                   MD
# ZIP                              21218-2688
# ADM_RATE                             0.1254
# UGDS                                   5663
# TUITIONFEE_IN                         52170
# MN_EARN_WNE_P10                         NaN
# Name: 1473, dtype: object

# %% [markdown]
# Calculating the min, max, and average in-state tution of the above four institutions.

# %%
print(df1['TUITIONFEE_IN'].min())
print(df1['TUITIONFEE_IN'].max())
print(df1['TUITIONFEE_IN'].mean())
# Out:
# 10399.0
# 52170.0
# 30411.75

# %% [markdown]
# Colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia

# %%
result=pd.DataFrame(columns=['UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'ADM_RATE', 'UGDS', 'TUITIONFEE_IN', 'MN_EARN_WNE_P10'])
states = ['VA','MD','WA','PA','DE']
for index in range(len(df)):
  if df.loc[index,'STABBR'] in states:
    result = result.append(df.loc[index])

# %%
result.to_csv("Five_States_Colleges.csv")
